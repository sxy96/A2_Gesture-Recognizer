# %% [markdown]
# # Report

# %% [markdown]
# ### (i)	A description of your shape matching approach and its performance including overall accuracy, per-gesture accuracy, and a confusion matrix;

# %% [markdown]
# [Description]

# %% [markdown]
#  I used fastdtw to build my shape matching function. The classifier function "dtwPredict(trial, trainFolds)"
# takes the trial to be predicted and all the training data stored in trainFolds as inputs, calculating the average
# euclidean distance from the trial to each type of gestures (taking their accelerometer magnitudes in calculation),
# and return the name of the gesture which has the closest average distance to the trial.

# %% [markdown]
# [Performance]

# %% [markdown]
# With Jon's Gesture Set

# %% [markdown]
# ![Confusion%20matrix_Jon%20gestures.png](attachment:Confusion%20matrix_Jon%20gestures.png)

# %% [markdown]
# With my Gesture Set

# %% [markdown]
# ![cm_DtwMyGestrue.png](attachment:cm_DtwMyGestrue.png)

# %% [markdown]
# ### (ii) a description of your model-based classification approach and its performance including overall accuracy, per-gesture accuracy, and a confusion matrix;

# %% [markdown]
# [Performance]

# %% [markdown]
# With Jon's Gesture

# %% [markdown]
# ![cm_SvmJonGesture.png](attachment:cm_SvmJonGesture.png)

# %% [markdown]
# With my Gesture Set

# %% [markdown]
# ![cm_SvmMyGesture.png](attachment:cm_SvmMyGesture.png)

# %% [markdown]
# ### (iii) an enumeration of key challenges;

# %% [markdown]
# (1) When two sets of gesture were put together, the accuracy dramatically decreased compared to
# (2) I haven't figured a way to

# %% [markdown]
# ### (iv) and a reflection of what you learned. You can include as many images as you want (e.g., copy/pasted from your Notebook).

# %% [markdown]
# I learned sooooo much by doing this assignment. This is the first time I actually write codes in Python
